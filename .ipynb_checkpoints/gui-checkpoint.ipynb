# %% [markdown]
# # Prim's Algorithm

# %%
from main import Graph

# %%
g = Graph()
'''
g.graph = \
    [   [0, 2, 0, 6, 0],
        [2, 0, 3, 8, 5],
        [0, 3, 0, 0, 7],
        [6, 8, 0, 0, 9],
        [0, 5, 7, 9, 0]]
'''
g.draw_adjacency_matrix()
# Out:
#   File "<ipython-input-3-84a5aaabafda>", line 3
#     [   [0, 2, 0, 6, 0],
#     ^
# IndentationError: unexpected indent

# %%
g.set_edge(4, 1, 6)
g.draw_adjacency_matrix()

# %%
g.draw_MST()
# Out:
# Edge 	Weight
# 0 - 1 	 2
# 1 - 2 	 3
# 0 - 3 	 6
# 1 - 4 	 6
