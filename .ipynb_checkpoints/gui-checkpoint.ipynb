# %% [markdown]
# # Prim's Algorithm

# %%
from main import Graph
# Out:
# Edge 	Weight
# 0 - 1 	 2
# 1 - 2 	 3
# 0 - 3 	 6
# 1 - 4 	 5
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_agraph.py in write_dot(G, path)
#     187     try:
# --> 188         import pygraphviz
#     189     except ImportError:
#
# ModuleNotFoundError: No module named 'pygraphviz'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-82bca9da5407> in <module>
# ----> 1 from main import Graph
#
# ~/Desktop/CPSC447/cpsc437-project/main.py in <module>
#     102
#     103 # g.display_graph()
# --> 104 g.draw_adjacency_matrix()
#
# ~/Desktop/CPSC447/cpsc437-project/main.py in draw_adjacency_matrix(self)
#      90                 G = nx.from_numpy_matrix(np.array(self.graph))
# ...

# %%
g = Graph(5)
g.graph = \
    [   [0, 2, 0, 6, 0],
        [2, 0, 3, 8, 5],
        [0, 3, 0, 0, 7],
        [6, 8, 0, 0, 9],
        [0, 5, 7, 9, 0]]

g.draw_adjacency_matrix()
# Out:
# Edge 	Weight
# 0 - 1 	 2
# 1 - 2 	 3
# 0 - 3 	 6
# 1 - 4 	 5
