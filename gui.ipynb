# %% [markdown]
# # Prim's Algorithm

# %%
from main import Graph

# %%
g = Graph(5)
g.graph = \
    [   [0, 2, 0, 6, 0],
        [2, 0, 3, 8, 5],
        [0, 3, 0, 0, 7],
        [6, 8, 0, 0, 9],
        [0, 5, 7, 9, 0]]

g.draw_adjacency_matrix()

# %%
g.primMST()
# Out:
# Edge 	Weight
# 0 - 1 	 2
# 1 - 2 	 3
# 0 - 3 	 6
# 1 - 4 	 5

# %%
g.draw_MST()
# Out:
# edges: [(0, 1), (0, 3), (1, 2), (1, 3), (1, 4), (2, 4), (3, 4)]
# colors: ['r', 'r', 'r', 'black', 'r', 'black', 'black']
